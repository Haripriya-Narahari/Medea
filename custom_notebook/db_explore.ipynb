# %%
import os
import ast
import pandas as pd
import torch

# %%
DB_PATH = os.path.join("..","database","MedeaDB")
PIN_PATH = os.path.join(DB_PATH,"pinnacle_embeds")

# %%
file_path = os.path.join(PIN_PATH, "pinnacle_labels_dict.txt")
if os.path.exists(file_path):
    with open(file_path, "r") as f:
        dict_str = f.read()
        labels_dict = ast.literal_eval(dict_str)
    print(type(labels_dict))
    #print(labels_dict)
else:
    print(f"File not found: {file_path}")
# Out:
# <class 'dict'>

# %%
labels_dict.keys()
# Out:
# dict_keys(['Cell Type', 'Name', 'Degree', 'Relative Degree', 'Overlap'])

# %%
name_list = labels_dict["Name"]
print(len(name_list), len(set(name_list)))
# Out:
# 395134 14017

# %%
cell_list = labels_dict["Cell Type"]
print(len(cell_list), len(set(cell_list)))
# Out:
# 395134 530

# %%
len(labels_dict["Degree"])
# Out:
# 395134

# %%
name_list[-10:]
# Out:
# ['Sanity Check mature nk t cell',
#  'Sanity Check mesenchymal stem cell',
#  'Sanity Check retinal blood vessel endothelial cell',
#  'Sanity Check mature enterocyte',
#  'Sanity Check macrophage',
#  'Sanity Check artery endothelial cell',
#  'Sanity Check pancreatic acinar cell',
#  'Sanity Check connective tissue cell',
#  'Sanity Check b cell',
#  'Sanity Check cd24 neutrophil']

# %%
cell_list[-10:]
# Out:
# ['Sanity Check mature nk t cell',
#  'Sanity Check mesenchymal stem cell',
#  'Sanity Check retinal blood vessel endothelial cell',
#  'Sanity Check mature enterocyte',
#  'Sanity Check macrophage',
#  'Sanity Check artery endothelial cell',
#  'Sanity Check pancreatic acinar cell',
#  'Sanity Check connective tissue cell',
#  'Sanity Check b cell',
#  'Sanity Check cd24 neutrophil']

# %%
labels_dict["Degree"]
# Out:
# [100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
# ...

# %%
len(labels_dict["Overlap"])
# Out:
# 395134

# %%
cell_typ_list = labels_dict["Cell Type"]
print(len(cell_typ_list))
# Out:
# 395134

# %%
pin_protein_embed = torch.load(os.path.join(PIN_PATH, "pinnacle_protein_embed.pth"))

# %%
print(pin_protein_embed.keys())
# Out:
# dict_keys([47, 51, 127, 13, 28, 105, 77, 129, 53, 99, 119, 100, 27, 46, 11, 153, 138, 17, 8, 35, 114, 22, 19, 42, 85, 37, 128, 36, 60, 0, 151, 126, 110, 116, 38, 52, 50, 104, 15, 23, 149, 143, 144, 103, 125, 76, 146, 70, 94, 150, 6, 95, 106, 43, 133, 20, 59, 121, 54, 80, 117, 55, 72, 145, 122, 48, 12, 41, 3, 111, 141, 49, 140, 101, 32, 66, 34, 78, 2, 14, 44, 45, 64, 102, 123, 74, 71, 130, 124, 148, 26, 18, 154, 21, 152, 90, 97, 82, 57, 139, 63, 58, 109, 24, 134, 40, 113, 108, 84, 9, 10, 56, 75, 155, 98, 131, 136, 39, 96, 115, 81, 30, 79, 73, 65, 92, 7, 83, 67, 68, 69, 142, 118, 33, 61, 87, 107, 137, 1, 91, 135, 31, 25, 120, 147, 62, 89, 93, 132, 88, 86, 4, 112, 29, 5, 16])

# %%
len(pin_protein_embed.keys())
# Out:
# 156

# %%
pin_protein_mg_embed = torch.load(os.path.join(PIN_PATH, "pinnacle_mg_embed.pth"))
print(pin_protein_mg_embed.shape)
# Out:
# torch.Size([218, 128])

# %%
pin_protein_embed[51].shape
# Out:
# torch.Size([1297, 128])
